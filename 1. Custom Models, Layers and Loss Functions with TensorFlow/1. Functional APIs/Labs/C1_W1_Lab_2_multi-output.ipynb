# %% [markdown]
# # Ungraded Lab: Build a Multi-output Model
#
# In this lab, we'll show how you can build models with more than one output. The dataset we will be working on is available from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Energy+efficiency). It is an Energy Efficiency dataset which uses the bulding features (e.g. wall area, roof area) as inputs and has two outputs: Cooling Load and Heating Load. Let's see how we can build a model to train on this data.

# %% [markdown]
# ## Imports

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Utilities
#
# We define a few utilities for data conversion and visualization to make our code more neat.

# %%
def format_output(data):
    y1 = data.pop('Y1')
    y1 = np.array(y1)
    y2 = data.pop('Y2')
    y2 = np.array(y2)
    return y1, y2


def norm(x):
    return (x - train_stats['mean']) / train_stats['std']


def plot_diff(y_true, y_pred, title=''):
    plt.scatter(y_true, y_pred)
    plt.title(title)
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.axis('equal')
    plt.axis('square')
    plt.xlim(plt.xlim())
    plt.ylim(plt.ylim())
    plt.plot([-100, 100], [-100, 100])
    plt.show()


def plot_metrics(metric_name, title, ylim=5):
    plt.title(title)
    plt.ylim(0, ylim)
    plt.plot(history.history[metric_name], color='blue', label=metric_name)
    plt.plot(history.history['val_' + metric_name], color='green', label='val_' + metric_name)
    plt.show()

# %% [markdown]
# ## Prepare the Data
#
# We download the dataset and format it for training.

# %%
# Get the data from UCI dataset
URL = 'https://archive.ics.uci.edu/ml/machine-learning-databases/00242/ENB2012_data.xlsx'

# Use pandas excel reader
df = pd.read_excel(URL)
df = df.sample(frac=1).reset_index(drop=True)

# Split the data into train and test with 80 train / 20 test
train, test = train_test_split(df, test_size=0.2)
train_stats = train.describe()

# Get Y1 and Y2 as the 2 outputs and format them as np arrays
train_stats.pop('Y1')
train_stats.pop('Y2')
train_stats = train_stats.transpose()
train_Y = format_output(train)
test_Y = format_output(test)

# Normalize the training and test data
norm_train_X = norm(train)
norm_test_X = norm(test)

# %% [markdown]
# ## Build the Model
#
# Here is how we'll build the model using the functional syntax. Notice that we can specify a list of outputs (i.e. `[y1_output, y2_output]`) when we instantiate the `Model()` class.

# %%
# Define model layers.
input_layer = Input(shape=(len(train .columns),))
first_dense = Dense(units='128', activation='relu')(input_layer)
second_dense = Dense(units='128', activation='relu')(first_dense)

# Y1 output will be fed directly from the second dense
y1_output = Dense(units='1', name='y1_output')(second_dense)
third_dense = Dense(units='64', activation='relu')(second_dense)

# Y2 output will come via the third dense
y2_output = Dense(units='1', name='y2_output')(third_dense)

# Define the model with the input layer and a list of output layers
model = Model(inputs=input_layer, outputs=[y1_output, y2_output])

print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 8)]          0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          1152        input_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 128)          16512       dense[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           8256        dense_1[0][0]
# __________________________________________________________________________________________________
# y1_output (Dense)               (None, 1)            129         dense_1[0][0]
# __________________________________________________________________________________________________
# y2_output (Dense)               (None, 1)            65          dense_2[0][0]
# ==================================================================================================
# Total params: 26,114
# Trainable params: 26,114
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# ## Configure parameters
#
# We specify the optimizer as well as the loss and metrics for each output.

# %%
# Specify the optimizer, and compile the model with loss functions for both outputs
optimizer = tf.keras.optimizers.SGD(lr=0.001)
model.compile(optimizer=optimizer,
              loss={'y1_output': 'mse', 'y2_output': 'mse'},
              metrics={'y1_output': tf.keras.metrics.RootMeanSquaredError(),
                       'y2_output': tf.keras.metrics.RootMeanSquaredError()})

# %% [markdown]
# ## Train the Model

# %%
# Train the model for 500 epochs
history = model.fit(norm_train_X, train_Y,
                    epochs=500, batch_size=10, validation_data=(norm_test_X, test_Y))
# Out:
# Train on 614 samples, validate on 154 samples
# Epoch 1/500
# 614/614 [==============================] - 1s 888us/sample - loss: 257.9148 - y1_output_loss: 120.3926 - y2_output_loss: 135.3066 - y1_output_root_mean_squared_error: 11.0192 - y2_output_root_mean_squared_error: 11.6830 - val_loss: 25.5913 - val_y1_output_loss: 11.9829 - val_y2_output_loss: 13.2044 - val_y1_output_root_mean_squared_error: 3.5046 - val_y2_output_root_mean_squared_error: 3.6481
# Epoch 2/500
# 614/614 [==============================] - 0s 136us/sample - loss: 33.3217 - y1_output_loss: 12.8306 - y2_output_loss: 20.3116 - y1_output_root_mean_squared_error: 3.5885 - y2_output_root_mean_squared_error: 4.5215 - val_loss: 19.0915 - val_y1_output_loss: 8.6041 - val_y2_output_loss: 10.0570 - val_y1_output_root_mean_squared_error: 2.9791 - val_y2_output_root_mean_squared_error: 3.1964
# Epoch 3/500
# 614/614 [==============================] - 0s 148us/sample - loss: 27.0216 - y1_output_loss: 10.4824 - y2_output_loss: 16.3573 - y1_output_root_mean_squared_error: 3.2483 - y2_output_root_mean_squared_error: 4.0583 - val_loss: 17.9241 - val_y1_output_loss: 8.5794 - val_y2_output_loss: 9.0145 - val_y1_output_root_mean_squared_error: 2.9646 - val_y2_output_root_mean_squared_error: 3.0224
# Epoch 4/500
# 614/614 [==============================] - 0s 129us/sample - loss: 27.5337 - y1_output_loss: 10.2047 - y2_output_loss: 17.0943 - y1_output_root_mean_squared_error: 3.2093 - y2_output_root_mean_squared_error: 4.1514 - val_loss: 18.1866 - val_y1_output_loss: 7.5266 - val_y2_output_loss: 10.3883 - val_y1_output_root_mean_squared_error: 2.7774 - val_y2_output_root_mean_squared_error: 3.2362
# Epoch 5/500
# 614/614 [==============================] - 0s 130us/sample - loss: 23.7782 - y1_output_loss: 9.1095 - y2_output_loss: 14.9366 - y1_output_root_mean_squared_error: 3.0214 - y2_output_root_mean_squared_error: 3.8274 - val_loss: 42.1179 - val_y1_output_loss: 11.4390 - val_y2_output_loss: 29.5223 - val_y1_output_root_mean_squared_error: 3.4455 - val_y2_output_root_mean_squared_error: 5.4996
# Epoch 6/500
# 614/614 [==============================] - 0s 127us/sample - loss: 23.4922 - y1_output_loss: 8.9606 - y2_output_loss: 14.6866 - y1_output_root_mean_squared_error: 2.9878 - y2_output_root_mean_squared_error: 3.8165 - val_loss: 15.8499 - val_y1_output_loss: 6.8666 - val_y2_output_loss: 8.5235 - val_y1_output_root_mean_squared_error: 2.6617 - val_y2_output_root_mean_squared_error: 2.9606
# Epoch 7/500
# 614/614 [==============================] - 0s 127us/sample - loss: 23.4913 - y1_output_loss: 9.0160 - y2_output_loss: 14.6321 - y1_output_root_mean_squared_error: 2.9822 - y2_output_root_mean_squared_error: 3.8207 - val_loss: 31.1665 - val_y1_output_loss: 12.2200 - val_y2_output_loss: 18.5229 - val_y1_output_root_mean_squared_error: 3.5296 - val_y2_output_root_mean_squared_error: 4.3253
# Epoch 8/500
# 614/614 [==============================] - 0s 126us/sample - loss: 20.6051 - y1_output_loss: 7.9872 - y2_output_loss: 12.5561 - y1_output_root_mean_squared_error: 2.8324 - y2_output_root_mean_squared_error: 3.5472 - val_loss: 33.5070 - val_y1_output_loss: 9.9137 - val_y2_output_loss: 22.7214 - val_y1_output_root_mean_squared_error: 3.2038 - val_y2_output_root_mean_squared_error: 4.8211
# Epoch 9/500
# 614/614 [==============================] - 0s 128us/sample - loss: 19.7168 - y1_output_loss: 7.8274 - y2_output_loss: 11.8414 - y1_output_root_mean_squared_error: 2.7931 - y2_output_root_mean_squared_error: 3.4519 - val_loss: 19.1951 - val_y1_output_loss: 8.6716 - val_y2_output_loss: 10.3600 - val_y1_output_root_mean_squared_error: 2.9623 - val_y2_output_root_mean_squared_error: 3.2280
# Epoch 10/500
# 614/614 [==============================] - 0s 131us/sample - loss: 23.9909 - y1_output_loss: 8.4335 - y2_output_loss: 16.1142 - y1_output_root_mean_squared_error: 2.8953 - y2_output_root_mean_squared_error: 3.9507 - val_loss: 97.1241 - val_y1_output_loss: 18.8403 - val_y2_output_loss: 78.6436 - val_y1_output_root_mean_squared_error: 4.3428 - val_y2_output_root_mean_squared_error: 8.8467
# Epoch 11/500
# 614/614 [==============================] - 0s 131us/sample - loss: 18.2511 - y1_output_loss: 7.2347 - y2_output_loss: 11.0408 - y1_output_root_mean_squared_error: 2.6761 - y2_output_root_mean_squared_error: 3.3301 - val_loss: 20.6170 - val_y1_output_loss: 8.5333 - val_y2_output_loss: 11.8364 - val_y1_output_root_mean_squared_error: 2.9465 - val_y2_output_root_mean_squared_error: 3.4548
# Epoch 12/500
# 614/614 [==============================] - 0s 126us/sample - loss: 19.0150 - y1_output_loss: 7.0638 - y2_output_loss: 11.7980 - y1_output_root_mean_squared_error: 2.6697 - y2_output_root_mean_squared_error: 3.4478 - val_loss: 14.2156 - val_y1_output_loss: 5.9789 - val_y2_output_loss: 7.7606 - val_y1_output_root_mean_squared_error: 2.4900 - val_y2_output_root_mean_squared_error: 2.8311
# Epoch 13/500
# 614/614 [==============================] - 0s 127us/sample - loss: 18.3119 - y1_output_loss: 6.8589 - y2_output_loss: 11.3184 - y1_output_root_mean_squared_error: 2.6282 - y2_output_root_mean_squared_error: 3.3771 - val_loss: 14.6647 - val_y1_output_loss: 5.9925 - val_y2_output_loss: 8.2247 - val_y1_output_root_mean_squared_error: 2.4904 - val_y2_output_root_mean_squared_error: 2.9091
# Epoch 14/500
# 614/614 [==============================] - 0s 128us/sample - loss: 17.2696 - y1_output_loss: 6.6305 - y2_output_loss: 10.5985 - y1_output_root_mean_squared_error: 2.5816 - y2_output_root_mean_squared_error: 3.2566 - val_loss: 24.7051 - val_y1_output_loss: 8.0693 - val_y2_output_loss: 15.9424 - val_y1_output_root_mean_squared_error: 2.8899 - val_y2_output_root_mean_squared_error: 4.0440
# Epoch 15/500
# 614/614 [==============================] - 0s 126us/sample - loss: 21.3399 - y1_output_loss: 7.0629 - y2_output_loss: 14.6093 - y1_output_root_mean_squared_error: 2.6144 - y2_output_root_mean_squared_error: 3.8085 - val_loss: 56.9122 - val_y1_output_loss: 22.2880 - val_y2_output_loss: 33.7179 - val_y1_output_root_mean_squared_error: 4.7696 - val_y2_output_root_mean_squared_error: 5.8449
# Epoch 16/500
# 614/614 [==============================] - 0s 127us/sample - loss: 16.3725 - y1_output_loss: 6.3655 - y2_output_loss: 10.2184 - y1_output_root_mean_squared_error: 2.5103 - y2_output_root_mean_squared_error: 3.1735 - val_loss: 58.5028 - val_y1_output_loss: 11.9032 - val_y2_output_loss: 45.6553 - val_y1_output_root_mean_squared_error: 3.4975 - val_y2_output_root_mean_squared_error: 6.8022
# Epoch 17/500
# 614/614 [==============================] - 0s 127us/sample - loss: 16.7248 - y1_output_loss: 6.2208 - y2_output_loss: 10.3937 - y1_output_root_mean_squared_error: 2.5006 - y2_output_root_mean_squared_error: 3.2360 - val_loss: 12.5119 - val_y1_output_loss: 5.5461 - val_y2_output_loss: 6.5652 - val_y1_output_root_mean_squared_error: 2.3956 - val_y2_output_root_mean_squared_error: 2.6025
# Epoch 18/500
# 614/614 [==============================] - 0s 128us/sample - loss: 16.1144 - y1_output_loss: 5.7546 - y2_output_loss: 10.2490 - y1_output_root_mean_squared_error: 2.4054 - y2_output_root_mean_squared_error: 3.2138 - val_loss: 14.5113 - val_y1_output_loss: 6.0700 - val_y2_output_loss: 8.3088 - val_y1_output_root_mean_squared_error: 2.4871 - val_y2_output_root_mean_squared_error: 2.8854
# Epoch 19/500
# 614/614 [==============================] - 0s 127us/sample - loss: 13.1773 - y1_output_loss: 5.2352 - y2_output_loss: 7.8975 - y1_output_root_mean_squared_error: 2.2906 - y2_output_root_mean_squared_error: 2.8161 - val_loss: 11.5937 - val_y1_output_loss: 4.8148 - val_y2_output_loss: 6.3992 - val_y1_output_root_mean_squared_error: 2.2344 - val_y2_output_root_mean_squared_error: 2.5693
# Epoch 20/500
# 614/614 [==============================] - 0s 128us/sample - loss: 14.3909 - y1_output_loss: 5.3524 - y2_output_loss: 8.9641 - y1_output_root_mean_squared_error: 2.3197 - y2_output_root_mean_squared_error: 3.0017 - val_loss: 12.2492 - val_y1_output_loss: 5.0447 - val_y2_output_loss: 6.7688 - val_y1_output_root_mean_squared_error: 2.2889 - val_y2_output_root_mean_squared_error: 2.6477
# Epoch 21/500
# 614/614 [==============================] - 0s 127us/sample - loss: 14.0286 - y1_output_loss: 5.2755 - y2_output_loss: 8.6888 - y1_output_root_mean_squared_error: 2.2986 - y2_output_root_mean_squared_error: 2.9572 - val_loss: 11.9137 - val_y1_output_loss: 5.2179 - val_y2_output_loss: 6.3566 - val_y1_output_root_mean_squared_error: 2.3186 - val_y2_output_root_mean_squared_error: 2.5569
# Epoch 22/500
# 614/614 [==============================] - 0s 128us/sample - loss: 13.7492 - y1_output_loss: 5.0944 - y2_output_loss: 8.6874 - y1_output_root_mean_squared_error: 2.2539 - y2_output_root_mean_squared_error: 2.9444 - val_loss: 12.1732 - val_y1_output_loss: 5.3339 - val_y2_output_loss: 6.5515 - val_y1_output_root_mean_squared_error: 2.3377 - val_y2_output_root_mean_squared_error: 2.5900
# Epoch 23/500
# 614/614 [==============================] - 0s 128us/sample - loss: 11.4849 - y1_output_loss: 4.6575 - y2_output_loss: 6.8142 - y1_output_root_mean_squared_error: 2.1632 - y2_output_root_mean_squared_error: 2.6087 - val_loss: 17.8084 - val_y1_output_loss: 4.9133 - val_y2_output_loss: 12.5024 - val_y1_output_root_mean_squared_error: 2.2558 - val_y2_output_root_mean_squared_error: 3.5664
# Epoch 24/500
# 614/614 [==============================] - 0s 128us/sample - loss: 13.1739 - y1_output_loss: 4.6338 - y2_output_loss: 8.4974 - y1_output_root_mean_squared_error: 2.1555 - y2_output_root_mean_squared_error: 2.9202 - val_loss: 17.9191 - val_y1_output_loss: 4.9396 - val_y2_output_loss: 12.4628 - val_y1_output_root_mean_squared_error: 2.2630 - val_y2_output_root_mean_squared_error: 3.5774
# Epoch 25/500
# 614/614 [==============================] - 0s 129us/sample - loss: 14.8932 - y1_output_loss: 5.3877 - y2_output_loss: 9.3900 - y1_output_root_mean_squared_error: 2.3315 - y2_output_root_mean_squared_error: 3.0753 - val_loss: 10.7626 - val_y1_output_loss: 4.3691 - val_y2_output_loss: 6.0255 - val_y1_output_root_mean_squared_error: 2.1300 - val_y2_output_root_mean_squared_error: 2.4951
# Epoch 26/500
# 614/614 [==============================] - 0s 129us/sample - loss: 12.8108 - y1_output_loss: 4.5125 - y2_output_loss: 8.1988 - y1_output_root_mean_squared_error: 2.1336 - y2_output_root_mean_squared_error: 2.8738 - val_loss: 10.2137 - val_y1_output_loss: 4.1101 - val_y2_output_loss: 5.7845 - val_y1_output_root_mean_squared_error: 2.0625 - val_y2_output_root_mean_squared_error: 2.4413
# Epoch 27/500
# 614/614 [==============================] - 0s 131us/sample - loss: 10.1132 - y1_output_loss: 3.8628 - y2_output_loss: 6.1677 - y1_output_root_mean_squared_error: 1.9746 - y2_output_root_mean_squared_error: 2.4928 - val_loss: 14.2828 - val_y1_output_loss: 5.7169 - val_y2_output_loss: 8.5808 - val_y1_output_root_mean_squared_error: 2.4027 - val_y2_output_root_mean_squared_error: 2.9172
# Epoch 28/500
# 614/614 [==============================] - 0s 127us/sample - loss: 12.1858 - y1_output_loss: 4.4854 - y2_output_loss: 7.7316 - y1_output_root_mean_squared_error: 2.1239 - y2_output_root_mean_squared_error: 2.7703 - val_loss: 17.5654 - val_y1_output_loss: 4.7919 - val_y2_output_loss: 12.2571 - val_y1_output_root_mean_squared_error: 2.2311 - val_y2_output_root_mean_squared_error: 3.5479
# Epoch 29/500
# 614/614 [==============================] - 0s 127us/sample - loss: 11.5053 - y1_output_loss: 3.9133 - y2_output_loss: 7.4880 - y1_output_root_mean_squared_error: 1.9870 - y2_output_root_mean_squared_error: 2.7490 - val_loss: 9.6885 - val_y1_output_loss: 3.8962 - val_y2_output_loss: 5.4961 - val_y1_output_root_mean_squared_error: 2.0077 - val_y2_output_root_mean_squared_error: 2.3786
# Epoch 30/500
# 614/614 [==============================] - 0s 129us/sample - loss: 11.9034 - y1_output_loss: 4.2821 - y2_output_loss: 7.5108 - y1_output_root_mean_squared_error: 2.0787 - y2_output_root_mean_squared_error: 2.7536 - val_loss: 11.8886 - val_y1_output_loss: 4.2329 - val_y2_output_loss: 7.2569 - val_y1_output_root_mean_squared_error: 2.0964 - val_y2_output_root_mean_squared_error: 2.7375
# Epoch 31/500
# 614/614 [==============================] - 0s 128us/sample - loss: 11.5081 - y1_output_loss: 4.0623 - y2_output_loss: 7.4034 - y1_output_root_mean_squared_error: 2.0109 - y2_output_root_mean_squared_error: 2.7321 - val_loss: 9.8305 - val_y1_output_loss: 4.0211 - val_y2_output_loss: 5.5977 - val_y1_output_root_mean_squared_error: 2.0347 - val_y2_output_root_mean_squared_error: 2.3855
# Epoch 32/500
# 614/614 [==============================] - 0s 131us/sample - loss: 12.7495 - y1_output_loss: 3.8384 - y2_output_loss: 8.9853 - y1_output_root_mean_squared_error: 1.9554 - y2_output_root_mean_squared_error: 2.9876 - val_loss: 27.5336 - val_y1_output_loss: 6.1860 - val_y2_output_loss: 21.3288 - val_y1_output_root_mean_squared_error: 2.5121 - val_y2_output_root_mean_squared_error: 4.6068
# Epoch 33/500
# 614/614 [==============================] - 0s 134us/sample - loss: 10.4382 - y1_output_loss: 3.6406 - y2_output_loss: 6.9249 - y1_output_root_mean_squared_error: 1.9062 - y2_output_root_mean_squared_error: 2.6086 - val_loss: 23.1200 - val_y1_output_loss: 3.9669 - val_y2_output_loss: 18.8942 - val_y1_output_root_mean_squared_error: 2.0155 - val_y2_output_root_mean_squared_error: 4.3655
# Epoch 34/500
# 614/614 [==============================] - 0s 131us/sample - loss: 13.9965 - y1_output_loss: 4.6653 - y2_output_loss: 9.3108 - y1_output_root_mean_squared_error: 2.1666 - y2_output_root_mean_squared_error: 3.0500 - val_loss: 9.1336 - val_y1_output_loss: 3.5974 - val_y2_output_loss: 5.2656 - val_y1_output_root_mean_squared_error: 1.9294 - val_y2_output_root_mean_squared_error: 2.3261
# Epoch 35/500
# 614/614 [==============================] - 0s 129us/sample - loss: 9.5283 - y1_output_loss: 3.1517 - y2_output_loss: 6.3997 - y1_output_root_mean_squared_error: 1.7781 - y2_output_root_mean_squared_error: 2.5232 - val_loss: 9.0706 - val_y1_output_loss: 3.8230 - val_y2_output_loss: 5.1802 - val_y1_output_root_mean_squared_error: 1.9722 - val_y2_output_root_mean_squared_error: 2.2762
# Epoch 36/500
# 614/614 [==============================] - 0s 127us/sample - loss: 8.3842 - y1_output_loss: 3.0259 - y2_output_loss: 5.4055 - y1_output_root_mean_squared_error: 1.7171 - y2_output_root_mean_squared_error: 2.3315 - val_loss: 9.6504 - val_y1_output_loss: 4.2988 - val_y2_output_loss: 5.0890 - val_y1_output_root_mean_squared_error: 2.1105 - val_y2_output_root_mean_squared_error: 2.2796
# Epoch 37/500
# 614/614 [==============================] - 0s 128us/sample - loss: 8.8322 - y1_output_loss: 2.9774 - y2_output_loss: 5.8065 - y1_output_root_mean_squared_error: 1.7315 - y2_output_root_mean_squared_error: 2.4154 - val_loss: 8.4008 - val_y1_output_loss: 2.7628 - val_y2_output_loss: 5.5032 - val_y1_output_root_mean_squared_error: 1.6896 - val_y2_output_root_mean_squared_error: 2.3550
# Epoch 38/500
# 614/614 [==============================] - 0s 127us/sample - loss: 9.5851 - y1_output_loss: 3.3524 - y2_output_loss: 6.3366 - y1_output_root_mean_squared_error: 1.8240 - y2_output_root_mean_squared_error: 2.5016 - val_loss: 30.2420 - val_y1_output_loss: 8.2345 - val_y2_output_loss: 22.1147 - val_y1_output_root_mean_squared_error: 2.8821 - val_y2_output_root_mean_squared_error: 4.6835
# Epoch 39/500
# 614/614 [==============================] - 0s 134us/sample - loss: 9.6456 - y1_output_loss: 3.1082 - y2_output_loss: 6.6062 - y1_output_root_mean_squared_error: 1.7626 - y2_output_root_mean_squared_error: 2.5571 - val_loss: 8.6442 - val_y1_output_loss: 3.5197 - val_y2_output_loss: 5.0897 - val_y1_output_root_mean_squared_error: 1.8884 - val_y2_output_root_mean_squared_error: 2.2535
# Epoch 40/500
# 614/614 [==============================] - 0s 137us/sample - loss: 8.7729 - y1_output_loss: 2.9362 - y2_output_loss: 5.7582 - y1_output_root_mean_squared_error: 1.7211 - y2_output_root_mean_squared_error: 2.4106 - val_loss: 7.5400 - val_y1_output_loss: 2.7456 - val_y2_output_loss: 4.6080 - val_y1_output_root_mean_squared_error: 1.6814 - val_y2_output_root_mean_squared_error: 2.1709
# Epoch 41/500
# 614/614 [==============================] - 0s 183us/sample - loss: 8.0556 - y1_output_loss: 2.6532 - y2_output_loss: 5.3819 - y1_output_root_mean_squared_error: 1.6232 - y2_output_root_mean_squared_error: 2.3283 - val_loss: 6.6543 - val_y1_output_loss: 2.4917 - val_y2_output_loss: 4.0268 - val_y1_output_root_mean_squared_error: 1.6043 - val_y2_output_root_mean_squared_error: 2.0200
# Epoch 42/500
# 614/614 [==============================] - 0s 157us/sample - loss: 8.1923 - y1_output_loss: 2.5228 - y2_output_loss: 5.6294 - y1_output_root_mean_squared_error: 1.5891 - y2_output_root_mean_squared_error: 2.3806 - val_loss: 7.8888 - val_y1_output_loss: 2.6110 - val_y2_output_loss: 5.2058 - val_y1_output_root_mean_squared_error: 1.6368 - val_y2_output_root_mean_squared_error: 2.2825
# Epoch 43/500
# 614/614 [==============================] - 0s 135us/sample - loss: 7.6463 - y1_output_loss: 2.4288 - y2_output_loss: 5.1504 - y1_output_root_mean_squared_error: 1.5652 - y2_output_root_mean_squared_error: 2.2795 - val_loss: 6.6484 - val_y1_output_loss: 2.2378 - val_y2_output_loss: 4.2645 - val_y1_output_root_mean_squared_error: 1.5185 - val_y2_output_root_mean_squared_error: 2.0839
# Epoch 44/500
# 614/614 [==============================] - 0s 129us/sample - loss: 7.3816 - y1_output_loss: 2.3254 - y2_output_loss: 5.1714 - y1_output_root_mean_squared_error: 1.5159 - y2_output_root_mean_squared_error: 2.2547 - val_loss: 7.9729 - val_y1_output_loss: 2.2794 - val_y2_output_loss: 5.5361 - val_y1_output_root_mean_squared_error: 1.5315 - val_y2_output_root_mean_squared_error: 2.3722
# Epoch 45/500
# 614/614 [==============================] - 0s 127us/sample - loss: 6.9517 - y1_output_loss: 2.2387 - y2_output_loss: 4.8417 - y1_output_root_mean_squared_error: 1.4954 - y2_output_root_mean_squared_error: 2.1715 - val_loss: 15.0876 - val_y1_output_loss: 3.3646 - val_y2_output_loss: 11.7648 - val_y1_output_root_mean_squared_error: 1.8312 - val_y2_output_root_mean_squared_error: 3.4255
# Epoch 46/500
# 614/614 [==============================] - 0s 127us/sample - loss: 7.6448 - y1_output_loss: 2.4085 - y2_output_loss: 5.1878 - y1_output_root_mean_squared_error: 1.5524 - y2_output_root_mean_squared_error: 2.2880 - val_loss: 7.1476 - val_y1_output_loss: 2.4662 - val_y2_output_loss: 4.5607 - val_y1_output_root_mean_squared_error: 1.5892 - val_y2_output_root_mean_squared_error: 2.1499
# Epoch 47/500
# 614/614 [==============================] - 0s 133us/sample - loss: 6.2819 - y1_output_loss: 1.9682 - y2_output_loss: 4.3247 - y1_output_root_mean_squared_error: 1.3983 - y2_output_root_mean_squared_error: 2.0800 - val_loss: 7.2304 - val_y1_output_loss: 2.4970 - val_y2_output_loss: 4.6612 - val_y1_output_root_mean_squared_error: 1.5983 - val_y2_output_root_mean_squared_error: 2.1624
# Epoch 48/500
# 614/614 [==============================] - 0s 132us/sample - loss: 6.7115 - y1_output_loss: 2.1991 - y2_output_loss: 4.5207 - y1_output_root_mean_squared_error: 1.4814 - y2_output_root_mean_squared_error: 2.1253 - val_loss: 6.3424 - val_y1_output_loss: 2.3198 - val_y2_output_loss: 4.0204 - val_y1_output_root_mean_squared_error: 1.5274 - val_y2_output_root_mean_squared_error: 2.0023
# Epoch 49/500
# 614/614 [==============================] - 0s 127us/sample - loss: 6.9241 - y1_output_loss: 2.0015 - y2_output_loss: 4.8982 - y1_output_root_mean_squared_error: 1.4212 - y2_output_root_mean_squared_error: 2.2145 - val_loss: 7.0709 - val_y1_output_loss: 2.4658 - val_y2_output_loss: 4.5000 - val_y1_output_root_mean_squared_error: 1.5883 - val_y2_output_root_mean_squared_error: 2.1326
# Epoch 50/500
# 614/614 [==============================] - 0s 134us/sample - loss: 9.5086 - y1_output_loss: 2.8960 - y2_output_loss: 6.6656 - y1_output_root_mean_squared_error: 1.6995 - y2_output_root_mean_squared_error: 2.5730 - val_loss: 26.4447 - val_y1_output_loss: 4.9165 - val_y2_output_loss: 21.6879 - val_y1_output_root_mean_squared_error: 2.2083 - val_y2_output_root_mean_squared_error: 4.6441
# Epoch 51/500
# 614/614 [==============================] - 0s 127us/sample - loss: 9.1699 - y1_output_loss: 2.9340 - y2_output_loss: 6.4005 - y1_output_root_mean_squared_error: 1.6932 - y2_output_root_mean_squared_error: 2.5106 - val_loss: 40.9984 - val_y1_output_loss: 12.1829 - val_y2_output_loss: 28.8444 - val_y1_output_root_mean_squared_error: 3.5033 - val_y2_output_root_mean_squared_error: 5.3596
# Epoch 52/500
# 614/614 [==============================] - 0s 128us/sample - loss: 9.3382 - y1_output_loss: 2.9758 - y2_output_loss: 6.4113 - y1_output_root_mean_squared_error: 1.7261 - y2_output_root_mean_squared_error: 2.5217 - val_loss: 9.3437 - val_y1_output_loss: 2.2383 - val_y2_output_loss: 6.9411 - val_y1_output_root_mean_squared_error: 1.5124 - val_y2_output_root_mean_squared_error: 2.6564
# Epoch 53/500
# 614/614 [==============================] - 0s 131us/sample - loss: 6.1336 - y1_output_loss: 1.9447 - y2_output_loss: 4.2744 - y1_output_root_mean_squared_error: 1.3956 - y2_output_root_mean_squared_error: 2.0460 - val_loss: 20.8198 - val_y1_output_loss: 3.6688 - val_y2_output_loss: 17.0522 - val_y1_output_root_mean_squared_error: 1.9215 - val_y2_output_root_mean_squared_error: 4.1386
# Epoch 54/500
# 614/614 [==============================] - 0s 127us/sample - loss: 6.9613 - y1_output_loss: 2.1544 - y2_output_loss: 5.0758 - y1_output_root_mean_squared_error: 1.4384 - y2_output_root_mean_squared_error: 2.2119 - val_loss: 48.6231 - val_y1_output_loss: 17.0069 - val_y2_output_loss: 31.9577 - val_y1_output_root_mean_squared_error: 4.1239 - val_y2_output_root_mean_squared_error: 5.6228
# Epoch 55/500
# 614/614 [==============================] - 0s 124us/sample - loss: 8.8717 - y1_output_loss: 2.8693 - y2_output_loss: 6.0475 - y1_output_root_mean_squared_error: 1.7019 - y2_output_root_mean_squared_error: 2.4444 - val_loss: 6.2578 - val_y1_output_loss: 2.1082 - val_y2_output_loss: 4.1110 - val_y1_output_root_mean_squared_error: 1.4633 - val_y2_output_root_mean_squared_error: 2.0290
# Epoch 56/500
# 614/614 [==============================] - 0s 125us/sample - loss: 5.8089 - y1_output_loss: 1.6767 - y2_output_loss: 4.1264 - y1_output_root_mean_squared_error: 1.2962 - y2_output_root_mean_squared_error: 2.0319 - val_loss: 11.5192 - val_y1_output_loss: 3.5965 - val_y2_output_loss: 7.9895 - val_y1_output_root_mean_squared_error: 1.9011 - val_y2_output_root_mean_squared_error: 2.8116
# Epoch 57/500
# 614/614 [==============================] - 0s 143us/sample - loss: 8.9418 - y1_output_loss: 2.6881 - y2_output_loss: 6.1963 - y1_output_root_mean_squared_error: 1.6417 - y2_output_root_mean_squared_error: 2.4993 - val_loss: 6.5787 - val_y1_output_loss: 1.9684 - val_y2_output_loss: 4.4965 - val_y1_output_root_mean_squared_error: 1.4188 - val_y2_output_root_mean_squared_error: 2.1368
# Epoch 58/500
# 614/614 [==============================] - 0s 134us/sample - loss: 5.6227 - y1_output_loss: 1.6557 - y2_output_loss: 3.9156 - y1_output_root_mean_squared_error: 1.2924 - y2_output_root_mean_squared_error: 1.9881 - val_loss: 5.1864 - val_y1_output_loss: 1.7219 - val_y2_output_loss: 3.4988 - val_y1_output_root_mean_squared_error: 1.3145 - val_y2_output_root_mean_squared_error: 1.8597
# Epoch 59/500
# 614/614 [==============================] - 0s 131us/sample - loss: 6.1081 - y1_output_loss: 1.7093 - y2_output_loss: 4.3863 - y1_output_root_mean_squared_error: 1.3118 - y2_output_root_mean_squared_error: 2.0946 - val_loss: 8.4951 - val_y1_output_loss: 1.9491 - val_y2_output_loss: 6.4233 - val_y1_output_root_mean_squared_error: 1.4093 - val_y2_output_root_mean_squared_error: 2.5513
# Epoch 60/500
# 614/614 [==============================] - 0s 128us/sample - loss: 5.6179 - y1_output_loss: 1.6317 - y2_output_loss: 3.9736 - y1_output_root_mean_squared_error: 1.2761 - y2_output_root_mean_squared_error: 1.9974 - val_loss: 9.3669 - val_y1_output_loss: 1.8566 - val_y2_output_loss: 7.3558 - val_y1_output_root_mean_squared_error: 1.3750 - val_y2_output_root_mean_squared_error: 2.7343
# Epoch 61/500
# 614/614 [==============================] - 0s 127us/sample - loss: 6.3926 - y1_output_loss: 1.7229 - y2_output_loss: 4.6265 - y1_output_root_mean_squared_error: 1.3164 - y2_output_root_mean_squared_error: 2.1586 - val_loss: 6.3992 - val_y1_output_loss: 2.0770 - val_y2_output_loss: 4.3793 - val_y1_output_root_mean_squared_error: 1.4400 - val_y2_output_root_mean_squared_error: 2.0798
# Epoch 62/500
# 614/614 [==============================] - 0s 127us/sample - loss: 5.5707 - y1_output_loss: 1.5309 - y2_output_loss: 4.1221 - y1_output_root_mean_squared_error: 1.2231 - y2_output_root_mean_squared_error: 2.0186 - val_loss: 23.4396 - val_y1_output_loss: 8.1367 - val_y2_output_loss: 15.8463 - val_y1_output_root_mean_squared_error: 2.8259 - val_y2_output_root_mean_squared_error: 3.9312
# Epoch 63/500
# 614/614 [==============================] - 0s 127us/sample - loss: 6.2707 - y1_output_loss: 1.8965 - y2_output_loss: 4.3177 - y1_output_root_mean_squared_error: 1.3834 - y2_output_root_mean_squared_error: 2.0873 - val_loss: 6.4558 - val_y1_output_loss: 1.4808 - val_y2_output_loss: 4.8806 - val_y1_output_root_mean_squared_error: 1.2281 - val_y2_output_root_mean_squared_error: 2.2243
# Epoch 64/500
# 614/614 [==============================] - 0s 126us/sample - loss: 5.5122 - y1_output_loss: 1.5149 - y2_output_loss: 3.9909 - y1_output_root_mean_squared_error: 1.2243 - y2_output_root_mean_squared_error: 2.0033 - val_loss: 8.6831 - val_y1_output_loss: 3.2624 - val_y2_output_loss: 5.4861 - val_y1_output_root_mean_squared_error: 1.8069 - val_y2_output_root_mean_squared_error: 2.3277
# Epoch 65/500
# 614/614 [==============================] - 0s 127us/sample - loss: 4.6017 - y1_output_loss: 1.2319 - y2_output_loss: 3.3912 - y1_output_root_mean_squared_error: 1.1111 - y2_output_root_mean_squared_error: 1.8350 - val_loss: 4.6393 - val_y1_output_loss: 1.2085 - val_y2_output_loss: 3.3965 - val_y1_output_root_mean_squared_error: 1.1101 - val_y2_output_root_mean_squared_error: 1.8458
# Epoch 66/500
# 614/614 [==============================] - 0s 127us/sample - loss: 4.5003 - y1_output_loss: 1.2169 - y2_output_loss: 3.2634 - y1_output_root_mean_squared_error: 1.1083 - y2_output_root_mean_squared_error: 1.8089 - val_loss: 7.1138 - val_y1_output_loss: 1.3806 - val_y2_output_loss: 5.6649 - val_y1_output_root_mean_squared_error: 1.1830 - val_y2_output_root_mean_squared_error: 2.3904
# Epoch 67/500
# 614/614 [==============================] - 0s 127us/sample - loss: 4.7383 - y1_output_loss: 1.1695 - y2_output_loss: 3.5335 - y1_output_root_mean_squared_error: 1.0844 - y2_output_root_mean_squared_error: 1.8874 - val_loss: 4.3681 - val_y1_output_loss: 1.3332 - val_y2_output_loss: 2.9877 - val_y1_output_root_mean_squared_error: 1.1669 - val_y2_output_root_mean_squared_error: 1.7339
# Epoch 68/500
# 614/614 [==============================] - 0s 136us/sample - loss: 3.7479 - y1_output_loss: 0.9682 - y2_output_loss: 2.8219 - y1_output_root_mean_squared_error: 0.9839 - y2_output_root_mean_squared_error: 1.6673 - val_loss: 4.4797 - val_y1_output_loss: 1.0840 - val_y2_output_loss: 3.3774 - val_y1_output_root_mean_squared_error: 1.0526 - val_y2_output_root_mean_squared_error: 1.8362
# Epoch 69/500
# 614/614 [==============================] - 0s 129us/sample - loss: 4.8809 - y1_output_loss: 1.1883 - y2_output_loss: 3.7219 - y1_output_root_mean_squared_error: 1.0883 - y2_output_root_mean_squared_error: 1.9226 - val_loss: 11.1745 - val_y1_output_loss: 1.6775 - val_y2_output_loss: 9.5580 - val_y1_output_root_mean_squared_error: 1.3037 - val_y2_output_root_mean_squared_error: 3.0781
# Epoch 70/500
# 614/614 [==============================] - 0s 133us/sample - loss: 4.9141 - y1_output_loss: 1.1805 - y2_output_loss: 3.8588 - y1_output_root_mean_squared_error: 1.0906 - y2_output_root_mean_squared_error: 1.9299 - val_loss: 20.8827 - val_y1_output_loss: 2.4955 - val_y2_output_loss: 18.6936 - val_y1_output_root_mean_squared_error: 1.5742 - val_y2_output_root_mean_squared_error: 4.2901
# Epoch 71/500
# 614/614 [==============================] - 0s 130us/sample - loss: 5.3699 - y1_output_loss: 1.3285 - y2_output_loss: 4.0459 - y1_output_root_mean_squared_error: 1.1445 - y2_output_root_mean_squared_error: 2.0149 - val_loss: 5.7839 - val_y1_output_loss: 1.8909 - val_y2_output_loss: 3.8365 - val_y1_output_root_mean_squared_error: 1.3751 - val_y2_output_root_mean_squared_error: 1.9730
# Epoch 72/500
# 614/614 [==============================] - 0s 159us/sample - loss: 5.0589 - y1_output_loss: 1.3097 - y2_output_loss: 3.7354 - y1_output_root_mean_squared_error: 1.1472 - y2_output_root_mean_squared_error: 1.9346 - val_loss: 6.0756 - val_y1_output_loss: 1.8682 - val_y2_output_loss: 4.2562 - val_y1_output_root_mean_squared_error: 1.3636 - val_y2_output_root_mean_squared_error: 2.0533
# Epoch 73/500
# 614/614 [==============================] - 0s 131us/sample - loss: 6.1467 - y1_output_loss: 1.5232 - y2_output_loss: 4.5704 - y1_output_root_mean_squared_error: 1.2388 - y2_output_root_mean_squared_error: 2.1476 - val_loss: 4.7354 - val_y1_output_loss: 1.1632 - val_y2_output_loss: 3.4889 - val_y1_output_root_mean_squared_error: 1.0937 - val_y2_output_root_mean_squared_error: 1.8813
# Epoch 74/500
# 614/614 [==============================] - 0s 131us/sample - loss: 4.0845 - y1_output_loss: 0.9965 - y2_output_loss: 3.0609 - y1_output_root_mean_squared_error: 0.9992 - y2_output_root_mean_squared_error: 1.7567 - val_loss: 3.4209 - val_y1_output_loss: 0.7097 - val_y2_output_loss: 2.6644 - val_y1_output_root_mean_squared_error: 0.8554 - val_y2_output_root_mean_squared_error: 1.6399
# Epoch 75/500
# 614/614 [==============================] - 0s 130us/sample - loss: 4.5536 - y1_output_loss: 1.0609 - y2_output_loss: 3.5208 - y1_output_root_mean_squared_error: 1.0289 - y2_output_root_mean_squared_error: 1.8695 - val_loss: 3.9182 - val_y1_output_loss: 1.1292 - val_y2_output_loss: 2.7529 - val_y1_output_root_mean_squared_error: 1.0672 - val_y2_output_root_mean_squared_error: 1.6671
# Epoch 76/500
# 614/614 [==============================] - 0s 129us/sample - loss: 3.6647 - y1_output_loss: 0.8808 - y2_output_loss: 2.7973 - y1_output_root_mean_squared_error: 0.9344 - y2_output_root_mean_squared_error: 1.6708 - val_loss: 6.2362 - val_y1_output_loss: 1.4165 - val_y2_output_loss: 4.8965 - val_y1_output_root_mean_squared_error: 1.1877 - val_y2_output_root_mean_squared_error: 2.1967
# Epoch 77/500
# 614/614 [==============================] - 0s 128us/sample - loss: 3.1908 - y1_output_loss: 0.7255 - y2_output_loss: 2.4532 - y1_output_root_mean_squared_error: 0.8460 - y2_output_root_mean_squared_error: 1.5732 - val_loss: 3.4053 - val_y1_output_loss: 0.7274 - val_y2_output_loss: 2.6049 - val_y1_output_root_mean_squared_error: 0.8642 - val_y2_output_root_mean_squared_error: 1.6305
# Epoch 78/500
# 614/614 [==============================] - 0s 127us/sample - loss: 3.8312 - y1_output_loss: 0.9412 - y2_output_loss: 2.8922 - y1_output_root_mean_squared_error: 0.9742 - y2_output_root_mean_squared_error: 1.6977 - val_loss: 3.5986 - val_y1_output_loss: 0.7897 - val_y2_output_loss: 2.7279 - val_y1_output_root_mean_squared_error: 0.9017 - val_y2_output_root_mean_squared_error: 1.6690
# Epoch 79/500
# 614/614 [==============================] - 0s 127us/sample - loss: 6.8249 - y1_output_loss: 1.8706 - y2_output_loss: 4.9252 - y1_output_root_mean_squared_error: 1.3689 - y2_output_root_mean_squared_error: 2.2251 - val_loss: 5.7145 - val_y1_output_loss: 0.8765 - val_y2_output_loss: 4.7395 - val_y1_output_root_mean_squared_error: 0.9422 - val_y2_output_root_mean_squared_error: 2.1970
# Epoch 80/500
# 614/614 [==============================] - 0s 136us/sample - loss: 3.9946 - y1_output_loss: 0.9077 - y2_output_loss: 3.0703 - y1_output_root_mean_squared_error: 0.9554 - y2_output_root_mean_squared_error: 1.7555 - val_loss: 4.0393 - val_y1_output_loss: 0.7601 - val_y2_output_loss: 3.1772 - val_y1_output_root_mean_squared_error: 0.8841 - val_y2_output_root_mean_squared_error: 1.8049
# Epoch 81/500
# 614/614 [==============================] - 0s 130us/sample - loss: 2.8761 - y1_output_loss: 0.6201 - y2_output_loss: 2.2467 - y1_output_root_mean_squared_error: 0.7872 - y2_output_root_mean_squared_error: 1.5021 - val_loss: 2.9346 - val_y1_output_loss: 0.6050 - val_y2_output_loss: 2.2771 - val_y1_output_root_mean_squared_error: 0.7831 - val_y2_output_root_mean_squared_error: 1.5236
# Epoch 82/500
# 614/614 [==============================] - 0s 129us/sample - loss: 3.8157 - y1_output_loss: 0.8172 - y2_output_loss: 2.9805 - y1_output_root_mean_squared_error: 0.9035 - y2_output_root_mean_squared_error: 1.7319 - val_loss: 3.6960 - val_y1_output_loss: 1.1281 - val_y2_output_loss: 2.6207 - val_y1_output_root_mean_squared_error: 1.0536 - val_y2_output_root_mean_squared_error: 1.6081
# Epoch 83/500
# 614/614 [==============================] - 0s 128us/sample - loss: 3.5714 - y1_output_loss: 0.9342 - y2_output_loss: 2.7150 - y1_output_root_mean_squared_error: 0.9481 - y2_output_root_mean_squared_error: 1.6348 - val_loss: 34.0856 - val_y1_output_loss: 13.1856 - val_y2_output_loss: 20.6637 - val_y1_output_root_mean_squared_error: 3.6561 - val_y2_output_root_mean_squared_error: 4.5518
# Epoch 84/500
# 614/614 [==============================] - 0s 131us/sample - loss: 4.6434 - y1_output_loss: 1.1242 - y2_output_loss: 3.5101 - y1_output_root_mean_squared_error: 1.0620 - y2_output_root_mean_squared_error: 1.8750 - val_loss: 5.0217 - val_y1_output_loss: 0.7305 - val_y2_output_loss: 4.3086 - val_y1_output_root_mean_squared_error: 0.8601 - val_y2_output_root_mean_squared_error: 2.0693
# Epoch 85/500
# 614/614 [==============================] - 0s 130us/sample - loss: 2.8812 - y1_output_loss: 0.6574 - y2_output_loss: 2.2015 - y1_output_root_mean_squared_error: 0.8125 - y2_output_root_mean_squared_error: 1.4903 - val_loss: 3.0044 - val_y1_output_loss: 0.7894 - val_y2_output_loss: 2.1451 - val_y1_output_root_mean_squared_error: 0.8978 - val_y2_output_root_mean_squared_error: 1.4827
# Epoch 86/500
# 614/614 [==============================] - 0s 131us/sample - loss: 3.6842 - y1_output_loss: 0.8988 - y2_output_loss: 2.8449 - y1_output_root_mean_squared_error: 0.9511 - y2_output_root_mean_squared_error: 1.6672 - val_loss: 18.7715 - val_y1_output_loss: 4.0279 - val_y2_output_loss: 15.1538 - val_y1_output_root_mean_squared_error: 1.9847 - val_y2_output_root_mean_squared_error: 3.8513
# Epoch 87/500
# 614/614 [==============================] - 0s 130us/sample - loss: 2.9060 - y1_output_loss: 0.6224 - y2_output_loss: 2.3534 - y1_output_root_mean_squared_error: 0.7899 - y2_output_root_mean_squared_error: 1.5106 - val_loss: 5.8718 - val_y1_output_loss: 0.7216 - val_y2_output_loss: 5.0025 - val_y1_output_root_mean_squared_error: 0.8629 - val_y2_output_root_mean_squared_error: 2.2643
# Epoch 88/500
# 614/614 [==============================] - 0s 126us/sample - loss: 3.2101 - y1_output_loss: 0.6841 - y2_output_loss: 2.4984 - y1_output_root_mean_squared_error: 0.8300 - y2_output_root_mean_squared_error: 1.5878 - val_loss: 2.6597 - val_y1_output_loss: 0.5202 - val_y2_output_loss: 2.0726 - val_y1_output_root_mean_squared_error: 0.7305 - val_y2_output_root_mean_squared_error: 1.4581
# Epoch 89/500
# 614/614 [==============================] - 0s 127us/sample - loss: 3.0774 - y1_output_loss: 0.6397 - y2_output_loss: 2.4130 - y1_output_root_mean_squared_error: 0.8026 - y2_output_root_mean_squared_error: 1.5599 - val_loss: 3.4332 - val_y1_output_loss: 0.5329 - val_y2_output_loss: 2.8128 - val_y1_output_root_mean_squared_error: 0.7398 - val_y2_output_root_mean_squared_error: 1.6988
# Epoch 90/500
# 614/614 [==============================] - 0s 126us/sample - loss: 3.9916 - y1_output_loss: 0.9129 - y2_output_loss: 3.0464 - y1_output_root_mean_squared_error: 0.9593 - y2_output_root_mean_squared_error: 1.7525 - val_loss: 2.9837 - val_y1_output_loss: 0.6497 - val_y2_output_loss: 2.2714 - val_y1_output_root_mean_squared_error: 0.8162 - val_y2_output_root_mean_squared_error: 1.5223
# Epoch 91/500
# 614/614 [==============================] - 0s 126us/sample - loss: 3.3058 - y1_output_loss: 0.6616 - y2_output_loss: 2.6284 - y1_output_root_mean_squared_error: 0.8125 - y2_output_root_mean_squared_error: 1.6265 - val_loss: 4.2559 - val_y1_output_loss: 0.6893 - val_y2_output_loss: 3.4425 - val_y1_output_root_mean_squared_error: 0.8447 - val_y2_output_root_mean_squared_error: 1.8821
# Epoch 92/500
# 614/614 [==============================] - 0s 126us/sample - loss: 3.0039 - y1_output_loss: 0.6890 - y2_output_loss: 2.3039 - y1_output_root_mean_squared_error: 0.8322 - y2_output_root_mean_squared_error: 1.5203 - val_loss: 3.5743 - val_y1_output_loss: 0.6099 - val_y2_output_loss: 2.9557 - val_y1_output_root_mean_squared_error: 0.7894 - val_y2_output_root_mean_squared_error: 1.7179
# Epoch 93/500
# 614/614 [==============================] - 0s 128us/sample - loss: 3.0692 - y1_output_loss: 0.7761 - y2_output_loss: 2.2695 - y1_output_root_mean_squared_error: 0.8824 - y2_output_root_mean_squared_error: 1.5134 - val_loss: 2.9605 - val_y1_output_loss: 0.5178 - val_y2_output_loss: 2.3559 - val_y1_output_root_mean_squared_error: 0.7303 - val_y2_output_root_mean_squared_error: 1.5579
# Epoch 94/500
# 614/614 [==============================] - 0s 134us/sample - loss: 3.0815 - y1_output_loss: 0.6720 - y2_output_loss: 2.3976 - y1_output_root_mean_squared_error: 0.8169 - y2_output_root_mean_squared_error: 1.5538 - val_loss: 3.2936 - val_y1_output_loss: 0.5155 - val_y2_output_loss: 2.6771 - val_y1_output_root_mean_squared_error: 0.7308 - val_y2_output_root_mean_squared_error: 1.6612
# Epoch 95/500
# 614/614 [==============================] - 0s 128us/sample - loss: 2.8113 - y1_output_loss: 0.6022 - y2_output_loss: 2.1886 - y1_output_root_mean_squared_error: 0.7775 - y2_output_root_mean_squared_error: 1.4855 - val_loss: 2.4029 - val_y1_output_loss: 0.4615 - val_y2_output_loss: 1.8910 - val_y1_output_root_mean_squared_error: 0.6843 - val_y2_output_root_mean_squared_error: 1.3909
# Epoch 96/500
# 614/614 [==============================] - 0s 127us/sample - loss: 2.7475 - y1_output_loss: 0.7208 - y2_output_loss: 2.0284 - y1_output_root_mean_squared_error: 0.8507 - y2_output_root_mean_squared_error: 1.4226 - val_loss: 3.9055 - val_y1_output_loss: 0.8988 - val_y2_output_loss: 3.0100 - val_y1_output_root_mean_squared_error: 0.9505 - val_y2_output_root_mean_squared_error: 1.7327
# Epoch 97/500
# 614/614 [==============================] - 0s 127us/sample - loss: 2.8891 - y1_output_loss: 0.7111 - y2_output_loss: 2.1676 - y1_output_root_mean_squared_error: 0.8435 - y2_output_root_mean_squared_error: 1.4757 - val_loss: 3.0292 - val_y1_output_loss: 0.9765 - val_y2_output_loss: 2.0164 - val_y1_output_root_mean_squared_error: 0.9841 - val_y2_output_root_mean_squared_error: 1.4356
# Epoch 98/500
# 614/614 [==============================] - 0s 127us/sample - loss: 2.6648 - y1_output_loss: 0.5741 - y2_output_loss: 2.1047 - y1_output_root_mean_squared_error: 0.7580 - y2_output_root_mean_squared_error: 1.4457 - val_loss: 2.4814 - val_y1_output_loss: 0.4687 - val_y2_output_loss: 1.9798 - val_y1_output_root_mean_squared_error: 0.6912 - val_y2_output_root_mean_squared_error: 1.4155
# Epoch 99/500
# 614/614 [==============================] - 0s 137us/sample - loss: 2.3411 - y1_output_loss: 0.5081 - y2_output_loss: 1.8379 - y1_output_root_mean_squared_error: 0.7154 - y2_output_root_mean_squared_error: 1.3525 - val_loss: 5.3921 - val_y1_output_loss: 1.1191 - val_y2_output_loss: 4.3029 - val_y1_output_root_mean_squared_error: 1.0527 - val_y2_output_root_mean_squared_error: 2.0698
# Epoch 100/500
# 614/614 [==============================] - 0s 129us/sample - loss: 3.1635 - y1_output_loss: 0.6739 - y2_output_loss: 2.5435 - y1_output_root_mean_squared_error: 0.8074 - y2_output_root_mean_squared_error: 1.5848 - val_loss: 5.3350 - val_y1_output_loss: 1.8727 - val_y2_output_loss: 3.2862 - val_y1_output_root_mean_squared_error: 1.3934 - val_y2_output_root_mean_squared_error: 1.8421
# Epoch 101/500
# 614/614 [==============================] - 0s 130us/sample - loss: 3.1642 - y1_output_loss: 0.6475 - y2_output_loss: 2.4870 - y1_output_root_mean_squared_error: 0.8085 - y2_output_root_mean_squared_error: 1.5844 - val_loss: 2.3206 - val_y1_output_loss: 0.5069 - val_y2_output_loss: 1.7698 - val_y1_output_root_mean_squared_error: 0.7174 - val_y2_output_root_mean_squared_error: 1.3439
# Epoch 102/500
# 614/614 [==============================] - 0s 128us/sample - loss: 3.0548 - y1_output_loss: 0.7893 - y2_output_loss: 2.2523 - y1_output_root_mean_squared_error: 0.8891 - y2_output_root_mean_squared_error: 1.5048 - val_loss: 2.5636 - val_y1_output_loss: 0.4718 - val_y2_output_loss: 2.0641 - val_y1_output_root_mean_squared_error: 0.6898 - val_y2_output_root_mean_squared_error: 1.4449
# Epoch 103/500
# 614/614 [==============================] - 0s 138us/sample - loss: 2.3656 - y1_output_loss: 0.5585 - y2_output_loss: 1.7942 - y1_output_root_mean_squared_error: 0.7471 - y2_output_root_mean_squared_error: 1.3444 - val_loss: 2.2505 - val_y1_output_loss: 0.3604 - val_y2_output_loss: 1.8519 - val_y1_output_root_mean_squared_error: 0.6048 - val_y2_output_root_mean_squared_error: 1.3728
# Epoch 104/500
# 614/614 [==============================] - 0s 132us/sample - loss: 2.4178 - y1_output_loss: 0.4944 - y2_output_loss: 1.9346 - y1_output_root_mean_squared_error: 0.7056 - y2_output_root_mean_squared_error: 1.3856 - val_loss: 7.6496 - val_y1_output_loss: 0.9526 - val_y2_output_loss: 6.6760 - val_y1_output_root_mean_squared_error: 0.9791 - val_y2_output_root_mean_squared_error: 2.5867
# Epoch 105/500
# 614/614 [==============================] - 0s 126us/sample - loss: 3.3857 - y1_output_loss: 0.7585 - y2_output_loss: 2.6040 - y1_output_root_mean_squared_error: 0.8747 - y2_output_root_mean_squared_error: 1.6188 - val_loss: 2.2478 - val_y1_output_loss: 0.5225 - val_y2_output_loss: 1.6767 - val_y1_output_root_mean_squared_error: 0.7344 - val_y2_output_root_mean_squared_error: 1.3071
# Epoch 106/500
# 614/614 [==============================] - 0s 129us/sample - loss: 2.5075 - y1_output_loss: 0.6708 - y2_output_loss: 1.8238 - y1_output_root_mean_squared_error: 0.8191 - y2_output_root_mean_squared_error: 1.3552 - val_loss: 3.5598 - val_y1_output_loss: 1.0430 - val_y2_output_loss: 2.4378 - val_y1_output_root_mean_squared_error: 1.0384 - val_y2_output_root_mean_squared_error: 1.5753
# Epoch 107/500
# 614/614 [==============================] - 0s 132us/sample - loss: 2.4237 - y1_output_loss: 0.5968 - y2_output_loss: 1.9016 - y1_output_root_mean_squared_error: 0.7735 - y2_output_root_mean_squared_error: 1.3510 - val_loss: 8.3677 - val_y1_output_loss: 1.2790 - val_y2_output_loss: 7.3077 - val_y1_output_root_mean_squared_error: 1.1078 - val_y2_output_root_mean_squared_error: 2.6722
# Epoch 108/500
# 614/614 [==============================] - 0s 142us/sample - loss: 2.6095 - y1_output_loss: 0.5338 - y2_output_loss: 2.1077 - y1_output_root_mean_squared_error: 0.7297 - y2_output_root_mean_squared_error: 1.4412 - val_loss: 12.7122 - val_y1_output_loss: 3.5310 - val_y2_output_loss: 9.0299 - val_y1_output_root_mean_squared_error: 1.8948 - val_y2_output_root_mean_squared_error: 3.0203
# Epoch 109/500
# 614/614 [==============================] - 0s 128us/sample - loss: 2.5985 - y1_output_loss: 0.5352 - y2_output_loss: 2.0399 - y1_output_root_mean_squared_error: 0.7345 - y2_output_root_mean_squared_error: 1.4349 - val_loss: 2.1907 - val_y1_output_loss: 0.4457 - val_y2_output_loss: 1.7079 - val_y1_output_root_mean_squared_error: 0.6682 - val_y2_output_root_mean_squared_error: 1.3207
# Epoch 110/500
# 614/614 [==============================] - 0s 127us/sample - loss: 2.6046 - y1_output_loss: 0.6079 - y2_output_loss: 1.9842 - y1_output_root_mean_squared_error: 0.7823 - y2_output_root_mean_squared_error: 1.4116 - val_loss: 2.2822 - val_y1_output_loss: 0.5263 - val_y2_output_loss: 1.7075 - val_y1_output_root_mean_squared_error: 0.7335 - val_y2_output_root_mean_squared_error: 1.3207
# Epoch 111/500
# 614/614 [==============================] - 0s 131us/sample - loss: 5.2323 - y1_output_loss: 1.0768 - y2_output_loss: 4.1103 - y1_output_root_mean_squared_error: 1.0413 - y2_output_root_mean_squared_error: 2.0367 - val_loss: 2.2257 - val_y1_output_loss: 0.6575 - val_y2_output_loss: 1.5163 - val_y1_output_root_mean_squared_error: 0.8133 - val_y2_output_root_mean_squared_error: 1.2507
# Epoch 112/500
# 614/614 [==============================] - 0s 134us/sample - loss: 1.8752 - y1_output_loss: 0.4262 - y2_output_loss: 1.4476 - y1_output_root_mean_squared_error: 0.6539 - y2_output_root_mean_squared_error: 1.2032 - val_loss: 3.9123 - val_y1_output_loss: 0.5059 - val_y2_output_loss: 3.3629 - val_y1_output_root_mean_squared_error: 0.7149 - val_y2_output_root_mean_squared_error: 1.8442
# Epoch 113/500
# 614/614 [==============================] - 0s 134us/sample - loss: 2.0300 - y1_output_loss: 0.4725 - y2_output_loss: 1.5975 - y1_output_root_mean_squared_error: 0.6853 - y2_output_root_mean_squared_error: 1.2492 - val_loss: 5.8347 - val_y1_output_loss: 1.1329 - val_y2_output_loss: 4.6697 - val_y1_output_root_mean_squared_error: 1.0722 - val_y2_output_root_mean_squared_error: 2.1645
# Epoch 114/500
# 614/614 [==============================] - 0s 135us/sample - loss: 2.0176 - y1_output_loss: 0.4772 - y2_output_loss: 1.5316 - y1_output_root_mean_squared_error: 0.6924 - y2_output_root_mean_squared_error: 1.2402 - val_loss: 2.1802 - val_y1_output_loss: 0.4390 - val_y2_output_loss: 1.7068 - val_y1_output_root_mean_squared_error: 0.6691 - val_y2_output_root_mean_squared_error: 1.3163
# Epoch 115/500
# 614/614 [==============================] - 0s 136us/sample - loss: 1.9770 - y1_output_loss: 0.3886 - y2_output_loss: 1.6085 - y1_output_root_mean_squared_error: 0.6254 - y2_output_root_mean_squared_error: 1.2593 - val_loss: 4.2473 - val_y1_output_loss: 0.9270 - val_y2_output_loss: 3.3724 - val_y1_output_root_mean_squared_error: 0.9513 - val_y2_output_root_mean_squared_error: 1.8282
# Epoch 116/500
# 614/614 [==============================] - 0s 130us/sample - loss: 2.5533 - y1_output_loss: 0.5024 - y2_output_loss: 2.0680 - y1_output_root_mean_squared_error: 0.7118 - y2_output_root_mean_squared_error: 1.4306 - val_loss: 4.5759 - val_y1_output_loss: 0.5817 - val_y2_output_loss: 3.9426 - val_y1_output_root_mean_squared_error: 0.7741 - val_y2_output_root_mean_squared_error: 1.9941
# Epoch 117/500
# 614/614 [==============================] - 0s 127us/sample - loss: 2.6691 - y1_output_loss: 0.6045 - y2_output_loss: 2.0671 - y1_output_root_mean_squared_error: 0.7799 - y2_output_root_mean_squared_error: 1.4356 - val_loss: 3.1749 - val_y1_output_loss: 0.8819 - val_y2_output_loss: 2.3701 - val_y1_output_root_mean_squared_error: 0.9139 - val_y2_output_root_mean_squared_error: 1.5296
# Epoch 118/500
# 614/614 [==============================] - 0s 131us/sample - loss: 2.0531 - y1_output_loss: 0.3975 - y2_output_loss: 1.6467 - y1_output_root_mean_squared_error: 0.6290 - y2_output_root_mean_squared_error: 1.2874 - val_loss: 2.6203 - val_y1_output_loss: 0.7967 - val_y2_output_loss: 1.8312 - val_y1_output_root_mean_squared_error: 0.8810 - val_y2_output_root_mean_squared_error: 1.3580
# Epoch 119/500
# 614/614 [==============================] - 0s 129us/sample - loss: 3.9082 - y1_output_loss: 1.0099 - y2_output_loss: 2.8698 - y1_output_root_mean_squared_error: 1.0088 - y2_output_root_mean_squared_error: 1.7002 - val_loss: 3.7476 - val_y1_output_loss: 0.4319 - val_y2_output_loss: 3.2837 - val_y1_output_root_mean_squared_error: 0.6643 - val_y2_output_root_mean_squared_error: 1.8183
# Epoch 120/500
# 614/614 [==============================] - 0s 129us/sample - loss: 1.9856 - y1_output_loss: 0.4447 - y2_output_loss: 1.5325 - y1_output_root_mean_squared_error: 0.6657 - y2_output_root_mean_squared_error: 1.2420 - val_loss: 2.3042 - val_y1_output_loss: 0.7595 - val_y2_output_loss: 1.5275 - val_y1_output_root_mean_squared_error: 0.8599 - val_y2_output_root_mean_squared_error: 1.2509
# Epoch 121/500
# ...
# Epoch 461/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.4710 - y1_output_loss: 0.1441 - y2_output_loss: 0.3322 - y1_output_root_mean_squared_error: 0.3697 - y2_output_root_mean_squared_error: 0.5783 - val_loss: 1.1047 - val_y1_output_loss: 0.3383 - val_y2_output_loss: 0.7771 - val_y1_output_root_mean_squared_error: 0.5843 - val_y2_output_root_mean_squared_error: 0.8737
# Epoch 462/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.5612 - y1_output_loss: 0.1489 - y2_output_loss: 0.4109 - y1_output_root_mean_squared_error: 0.3847 - y2_output_root_mean_squared_error: 0.6428 - val_loss: 2.1167 - val_y1_output_loss: 0.6244 - val_y2_output_loss: 1.4538 - val_y1_output_root_mean_squared_error: 0.7991 - val_y2_output_root_mean_squared_error: 1.2158
# Epoch 463/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.4437 - y1_output_loss: 0.1320 - y2_output_loss: 0.3123 - y1_output_root_mean_squared_error: 0.3641 - y2_output_root_mean_squared_error: 0.5578 - val_loss: 0.9059 - val_y1_output_loss: 0.2182 - val_y2_output_loss: 0.6914 - val_y1_output_root_mean_squared_error: 0.4676 - val_y2_output_root_mean_squared_error: 0.8290
# Epoch 464/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.7654 - y1_output_loss: 0.1730 - y2_output_loss: 0.5861 - y1_output_root_mean_squared_error: 0.4172 - y2_output_root_mean_squared_error: 0.7690 - val_loss: 0.9045 - val_y1_output_loss: 0.1973 - val_y2_output_loss: 0.7211 - val_y1_output_root_mean_squared_error: 0.4500 - val_y2_output_root_mean_squared_error: 0.8379
# Epoch 465/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.3964 - y1_output_loss: 0.1102 - y2_output_loss: 0.2852 - y1_output_root_mean_squared_error: 0.3331 - y2_output_root_mean_squared_error: 0.5343 - val_loss: 0.9091 - val_y1_output_loss: 0.2157 - val_y2_output_loss: 0.6923 - val_y1_output_root_mean_squared_error: 0.4641 - val_y2_output_root_mean_squared_error: 0.8329
# Epoch 466/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.5297 - y1_output_loss: 0.1340 - y2_output_loss: 0.3965 - y1_output_root_mean_squared_error: 0.3669 - y2_output_root_mean_squared_error: 0.6285 - val_loss: 1.1402 - val_y1_output_loss: 0.1740 - val_y2_output_loss: 0.9422 - val_y1_output_root_mean_squared_error: 0.4242 - val_y2_output_root_mean_squared_error: 0.9799
# Epoch 467/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.4190 - y1_output_loss: 0.1193 - y2_output_loss: 0.2981 - y1_output_root_mean_squared_error: 0.3462 - y2_output_root_mean_squared_error: 0.5469 - val_loss: 1.3174 - val_y1_output_loss: 0.2679 - val_y2_output_loss: 1.0438 - val_y1_output_root_mean_squared_error: 0.5199 - val_y2_output_root_mean_squared_error: 1.0233
# Epoch 468/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.5241 - y1_output_loss: 0.1276 - y2_output_loss: 0.3951 - y1_output_root_mean_squared_error: 0.3579 - y2_output_root_mean_squared_error: 0.6293 - val_loss: 1.1474 - val_y1_output_loss: 0.2378 - val_y2_output_loss: 0.9108 - val_y1_output_root_mean_squared_error: 0.4914 - val_y2_output_root_mean_squared_error: 0.9518
# Epoch 469/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.5038 - y1_output_loss: 0.1423 - y2_output_loss: 0.3687 - y1_output_root_mean_squared_error: 0.3701 - y2_output_root_mean_squared_error: 0.6056 - val_loss: 2.1499 - val_y1_output_loss: 0.5745 - val_y2_output_loss: 1.5413 - val_y1_output_root_mean_squared_error: 0.7645 - val_y2_output_root_mean_squared_error: 1.2512
# Epoch 470/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.4433 - y1_output_loss: 0.1194 - y2_output_loss: 0.3232 - y1_output_root_mean_squared_error: 0.3467 - y2_output_root_mean_squared_error: 0.5684 - val_loss: 1.3799 - val_y1_output_loss: 0.3293 - val_y2_output_loss: 1.0556 - val_y1_output_root_mean_squared_error: 0.5744 - val_y2_output_root_mean_squared_error: 1.0247
# Epoch 471/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.9539 - y1_output_loss: 0.2374 - y2_output_loss: 0.7085 - y1_output_root_mean_squared_error: 0.4892 - y2_output_root_mean_squared_error: 0.8454 - val_loss: 0.9871 - val_y1_output_loss: 0.2318 - val_y2_output_loss: 0.7619 - val_y1_output_root_mean_squared_error: 0.4827 - val_y2_output_root_mean_squared_error: 0.8684
# Epoch 472/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.8769 - y1_output_loss: 0.2261 - y2_output_loss: 0.6475 - y1_output_root_mean_squared_error: 0.4768 - y2_output_root_mean_squared_error: 0.8059 - val_loss: 1.2478 - val_y1_output_loss: 0.2061 - val_y2_output_loss: 1.0149 - val_y1_output_root_mean_squared_error: 0.4609 - val_y2_output_root_mean_squared_error: 1.0175
# Epoch 473/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.4817 - y1_output_loss: 0.1269 - y2_output_loss: 0.3508 - y1_output_root_mean_squared_error: 0.3577 - y2_output_root_mean_squared_error: 0.5948 - val_loss: 0.8513 - val_y1_output_loss: 0.1834 - val_y2_output_loss: 0.6588 - val_y1_output_root_mean_squared_error: 0.4340 - val_y2_output_root_mean_squared_error: 0.8142
# Epoch 474/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.3805 - y1_output_loss: 0.1100 - y2_output_loss: 0.2707 - y1_output_root_mean_squared_error: 0.3315 - y2_output_root_mean_squared_error: 0.5202 - val_loss: 0.9295 - val_y1_output_loss: 0.1878 - val_y2_output_loss: 0.7208 - val_y1_output_root_mean_squared_error: 0.4415 - val_y2_output_root_mean_squared_error: 0.8571
# Epoch 475/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.4246 - y1_output_loss: 0.1157 - y2_output_loss: 0.3069 - y1_output_root_mean_squared_error: 0.3416 - y2_output_root_mean_squared_error: 0.5549 - val_loss: 1.1587 - val_y1_output_loss: 0.1786 - val_y2_output_loss: 0.9569 - val_y1_output_root_mean_squared_error: 0.4307 - val_y2_output_root_mean_squared_error: 0.9865
# Epoch 476/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.4353 - y1_output_loss: 0.1286 - y2_output_loss: 0.3130 - y1_output_root_mean_squared_error: 0.3463 - y2_output_root_mean_squared_error: 0.5616 - val_loss: 1.0123 - val_y1_output_loss: 0.3171 - val_y2_output_loss: 0.6749 - val_y1_output_root_mean_squared_error: 0.5714 - val_y2_output_root_mean_squared_error: 0.8282
# Epoch 477/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.5240 - y1_output_loss: 0.1555 - y2_output_loss: 0.3669 - y1_output_root_mean_squared_error: 0.3931 - y2_output_root_mean_squared_error: 0.6078 - val_loss: 0.9652 - val_y1_output_loss: 0.2314 - val_y2_output_loss: 0.7137 - val_y1_output_root_mean_squared_error: 0.4894 - val_y2_output_root_mean_squared_error: 0.8519
# Epoch 478/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.3758 - y1_output_loss: 0.1062 - y2_output_loss: 0.2711 - y1_output_root_mean_squared_error: 0.3260 - y2_output_root_mean_squared_error: 0.5191 - val_loss: 1.0433 - val_y1_output_loss: 0.2048 - val_y2_output_loss: 0.8139 - val_y1_output_root_mean_squared_error: 0.4566 - val_y2_output_root_mean_squared_error: 0.9137
# Epoch 479/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.4798 - y1_output_loss: 0.1156 - y2_output_loss: 0.3607 - y1_output_root_mean_squared_error: 0.3414 - y2_output_root_mean_squared_error: 0.6027 - val_loss: 0.9275 - val_y1_output_loss: 0.1816 - val_y2_output_loss: 0.7324 - val_y1_output_root_mean_squared_error: 0.4336 - val_y2_output_root_mean_squared_error: 0.8599
# Epoch 480/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.5096 - y1_output_loss: 0.1409 - y2_output_loss: 0.3652 - y1_output_root_mean_squared_error: 0.3760 - y2_output_root_mean_squared_error: 0.6068 - val_loss: 0.8517 - val_y1_output_loss: 0.2021 - val_y2_output_loss: 0.6492 - val_y1_output_root_mean_squared_error: 0.4532 - val_y2_output_root_mean_squared_error: 0.8039
# Epoch 481/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.3735 - y1_output_loss: 0.1085 - y2_output_loss: 0.2629 - y1_output_root_mean_squared_error: 0.3304 - y2_output_root_mean_squared_error: 0.5142 - val_loss: 0.8628 - val_y1_output_loss: 0.2191 - val_y2_output_loss: 0.6337 - val_y1_output_root_mean_squared_error: 0.4737 - val_y2_output_root_mean_squared_error: 0.7990
# Epoch 482/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.4832 - y1_output_loss: 0.1494 - y2_output_loss: 0.3414 - y1_output_root_mean_squared_error: 0.3752 - y2_output_root_mean_squared_error: 0.5851 - val_loss: 2.4096 - val_y1_output_loss: 0.9518 - val_y2_output_loss: 1.5566 - val_y1_output_root_mean_squared_error: 0.9633 - val_y2_output_root_mean_squared_error: 1.2173
# Epoch 483/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.4946 - y1_output_loss: 0.1511 - y2_output_loss: 0.3399 - y1_output_root_mean_squared_error: 0.3903 - y2_output_root_mean_squared_error: 0.5850 - val_loss: 0.9047 - val_y1_output_loss: 0.1973 - val_y2_output_loss: 0.6998 - val_y1_output_root_mean_squared_error: 0.4503 - val_y2_output_root_mean_squared_error: 0.8378
# Epoch 484/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.4695 - y1_output_loss: 0.1241 - y2_output_loss: 0.3451 - y1_output_root_mean_squared_error: 0.3534 - y2_output_root_mean_squared_error: 0.5870 - val_loss: 1.1327 - val_y1_output_loss: 0.1833 - val_y2_output_loss: 0.9268 - val_y1_output_root_mean_squared_error: 0.4341 - val_y2_output_root_mean_squared_error: 0.9717
# Epoch 485/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.4149 - y1_output_loss: 0.1288 - y2_output_loss: 0.2866 - y1_output_root_mean_squared_error: 0.3581 - y2_output_root_mean_squared_error: 0.5354 - val_loss: 1.3851 - val_y1_output_loss: 0.4514 - val_y2_output_loss: 0.9802 - val_y1_output_root_mean_squared_error: 0.6598 - val_y2_output_root_mean_squared_error: 0.9746
# Epoch 486/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.6432 - y1_output_loss: 0.1507 - y2_output_loss: 0.4919 - y1_output_root_mean_squared_error: 0.3867 - y2_output_root_mean_squared_error: 0.7026 - val_loss: 1.1852 - val_y1_output_loss: 0.2938 - val_y2_output_loss: 0.9386 - val_y1_output_root_mean_squared_error: 0.5365 - val_y2_output_root_mean_squared_error: 0.9473
# Epoch 487/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.5255 - y1_output_loss: 0.1471 - y2_output_loss: 0.3762 - y1_output_root_mean_squared_error: 0.3828 - y2_output_root_mean_squared_error: 0.6156 - val_loss: 0.9099 - val_y1_output_loss: 0.2145 - val_y2_output_loss: 0.6744 - val_y1_output_root_mean_squared_error: 0.4716 - val_y2_output_root_mean_squared_error: 0.8291
# Epoch 488/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.4023 - y1_output_loss: 0.1139 - y2_output_loss: 0.2870 - y1_output_root_mean_squared_error: 0.3382 - y2_output_root_mean_squared_error: 0.5365 - val_loss: 0.8452 - val_y1_output_loss: 0.1975 - val_y2_output_loss: 0.6431 - val_y1_output_root_mean_squared_error: 0.4517 - val_y2_output_root_mean_squared_error: 0.8007
# Epoch 489/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.5882 - y1_output_loss: 0.1560 - y2_output_loss: 0.4288 - y1_output_root_mean_squared_error: 0.3955 - y2_output_root_mean_squared_error: 0.6571 - val_loss: 1.0997 - val_y1_output_loss: 0.2286 - val_y2_output_loss: 0.8572 - val_y1_output_root_mean_squared_error: 0.4856 - val_y2_output_root_mean_squared_error: 0.9295
# Epoch 490/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.4165 - y1_output_loss: 0.1284 - y2_output_loss: 0.2937 - y1_output_root_mean_squared_error: 0.3568 - y2_output_root_mean_squared_error: 0.5378 - val_loss: 0.9547 - val_y1_output_loss: 0.1911 - val_y2_output_loss: 0.7563 - val_y1_output_root_mean_squared_error: 0.4433 - val_y2_output_root_mean_squared_error: 0.8707
# Epoch 491/500
# 614/614 [==============================] - 0s 140us/sample - loss: 1.0858 - y1_output_loss: 0.2650 - y2_output_loss: 0.8134 - y1_output_root_mean_squared_error: 0.5167 - y2_output_root_mean_squared_error: 0.9049 - val_loss: 0.9779 - val_y1_output_loss: 0.2096 - val_y2_output_loss: 0.7605 - val_y1_output_root_mean_squared_error: 0.4634 - val_y2_output_root_mean_squared_error: 0.8736
# Epoch 492/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.5365 - y1_output_loss: 0.1369 - y2_output_loss: 0.3981 - y1_output_root_mean_squared_error: 0.3700 - y2_output_root_mean_squared_error: 0.6321 - val_loss: 1.1804 - val_y1_output_loss: 0.2506 - val_y2_output_loss: 0.9674 - val_y1_output_root_mean_squared_error: 0.4987 - val_y2_output_root_mean_squared_error: 0.9653
# Epoch 493/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.5834 - y1_output_loss: 0.1301 - y2_output_loss: 0.4650 - y1_output_root_mean_squared_error: 0.3579 - y2_output_root_mean_squared_error: 0.6747 - val_loss: 4.5820 - val_y1_output_loss: 0.9593 - val_y2_output_loss: 3.5045 - val_y1_output_root_mean_squared_error: 0.9966 - val_y2_output_root_mean_squared_error: 1.8944
# Epoch 494/500
# 614/614 [==============================] - 0s 147us/sample - loss: 0.7504 - y1_output_loss: 0.1785 - y2_output_loss: 0.5685 - y1_output_root_mean_squared_error: 0.4235 - y2_output_root_mean_squared_error: 0.7557 - val_loss: 0.9900 - val_y1_output_loss: 0.1952 - val_y2_output_loss: 0.8181 - val_y1_output_root_mean_squared_error: 0.4448 - val_y2_output_root_mean_squared_error: 0.8900
# Epoch 495/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.4889 - y1_output_loss: 0.1214 - y2_output_loss: 0.3718 - y1_output_root_mean_squared_error: 0.3449 - y2_output_root_mean_squared_error: 0.6082 - val_loss: 1.5029 - val_y1_output_loss: 0.4585 - val_y2_output_loss: 1.0320 - val_y1_output_root_mean_squared_error: 0.6846 - val_y2_output_root_mean_squared_error: 1.0170
# Epoch 496/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.5381 - y1_output_loss: 0.1430 - y2_output_loss: 0.3911 - y1_output_root_mean_squared_error: 0.3790 - y2_output_root_mean_squared_error: 0.6280 - val_loss: 0.9158 - val_y1_output_loss: 0.2046 - val_y2_output_loss: 0.6966 - val_y1_output_root_mean_squared_error: 0.4601 - val_y2_output_root_mean_squared_error: 0.8391
# Epoch 497/500
# 614/614 [==============================] - 0s 154us/sample - loss: 0.4724 - y1_output_loss: 0.1242 - y2_output_loss: 0.3457 - y1_output_root_mean_squared_error: 0.3536 - y2_output_root_mean_squared_error: 0.5893 - val_loss: 0.8520 - val_y1_output_loss: 0.2005 - val_y2_output_loss: 0.6475 - val_y1_output_root_mean_squared_error: 0.4552 - val_y2_output_root_mean_squared_error: 0.8030
# Epoch 498/500
# 614/614 [==============================] - 0s 141us/sample - loss: 0.5203 - y1_output_loss: 0.1252 - y2_output_loss: 0.3936 - y1_output_root_mean_squared_error: 0.3554 - y2_output_root_mean_squared_error: 0.6277 - val_loss: 1.0140 - val_y1_output_loss: 0.2122 - val_y2_output_loss: 0.7862 - val_y1_output_root_mean_squared_error: 0.4690 - val_y2_output_root_mean_squared_error: 0.8911
# Epoch 499/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.4129 - y1_output_loss: 0.1221 - y2_output_loss: 0.2889 - y1_output_root_mean_squared_error: 0.3510 - y2_output_root_mean_squared_error: 0.5382 - val_loss: 0.8765 - val_y1_output_loss: 0.1999 - val_y2_output_loss: 0.6741 - val_y1_output_root_mean_squared_error: 0.4522 - val_y2_output_root_mean_squared_error: 0.8198
# Epoch 500/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.4394 - y1_output_loss: 0.1182 - y2_output_loss: 0.3222 - y1_output_root_mean_squared_error: 0.3447 - y2_output_root_mean_squared_error: 0.5662 - val_loss: 1.0364 - val_y1_output_loss: 0.2595 - val_y2_output_loss: 0.7729 - val_y1_output_root_mean_squared_error: 0.5152 - val_y2_output_root_mean_squared_error: 0.8781

# %% [markdown]
# ## Evaluate the Model and Plot Metrics

# %%
# Test the model and print loss and mse for both outputs
loss, Y1_loss, Y2_loss, Y1_rmse, Y2_rmse = model.evaluate(x=norm_test_X, y=test_Y)
print("Loss = {}, Y1_loss = {}, Y1_mse = {}, Y2_loss = {}, Y2_mse = {}".format(loss, Y1_loss, Y1_rmse, Y2_loss, Y2_rmse))
# Out:
# 154/154 [==============================] - 0s 34us/sample - loss: 1.0364 - y1_output_loss: 0.2623 - y2_output_loss: 0.7713 - y1_output_root_mean_squared_error: 0.5152 - y2_output_root_mean_squared_error: 0.8781
# Loss = 1.03640774550376, Y1_loss = 0.2623007893562317, Y1_mse = 0.5151786208152771, Y2_loss = 0.7713453769683838, Y2_mse = 0.878065288066864

# %%
# Plot the loss and mse
Y_pred = model.predict(norm_test_X)
plot_diff(test_Y[0], Y_pred[0], title='Y1')
plot_diff(test_Y[1], Y_pred[1], title='Y2')
plot_metrics(metric_name='y1_output_root_mean_squared_error', title='Y1 RMSE', ylim=6)
plot_metrics(metric_name='y2_output_root_mean_squared_error', title='Y2 RMSE', ylim=7)
